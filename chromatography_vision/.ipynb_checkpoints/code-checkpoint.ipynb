# %%
import numpy as np
import argparse
import cv2
import imutils
import matplotlib.pyplot as plt

# %%
# load the image and compute the ratio of the old height
# to the new height, clone it, and resize it
image = cv2.imread("images/c_1.jpg")

gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
# gray = cv2.GaussianBlur(gray, (1, 1), 0)

edged = cv2.Canny(gray, 20, 100)
print("STEP 1: Edge Detection")

plt.imshow(edged, cmap='gray')
plt.title("Edged image")
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# STEP 1: Edge Detection

# %%
#For better accuracy, use binary images. So before finding contours, apply threshold or canny edge detection.
img = cv2.imread('images/c_6.jpg')
imgray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

ret, thresh = cv2.threshold(imgray, 127, 255, 0)
im2, contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)

#To draw all the contours in an image:
cv2.drawContours(img, contours, 64, (0,255,0), 3) # total 65 contours, mail are at 64 and 65

#To draw an individual contour, say 4th contour:
# cv2.drawContours(img, contours, 3, (0,255,0), 3)

#But most of the time, below method will be useful:
# cnt = contours[1]
# cv2.drawContours(img, [cnt], 0, (0,255,0), 3)

plt.imshow(img)
plt.xticks([]), plt.yticks([])
plt.show();

# %%
import cv2
import numpy as np

cap = cv2.VideoCapture(0)

while(1):

    # Take each frame
    _, frame = cap.read()

    # Convert BGR to HSV
    hsv = cv2.cvtColor(frame, cv2.COLOR_BGR2HSV)

    # define range of blue color in HSV
    lower_blue = np.array([110,50,50])
    upper_blue = np.array([130,255,255])

    # Threshold the HSV image to get only blue colors
    mask = cv2.inRange(hsv, lower_blue, upper_blue)

    # Bitwise-AND mask and original image
    res = cv2.bitwise_and(frame,frame, mask= mask)

    cv2.imshow('frame',frame)
    cv2.imshow('mask',mask)
    cv2.imshow('res',res)
    k = cv2.waitKey(5) & 0xFF
    if k == 27:
        break

cv2.destroyAllWindows()

# %%
#let's extract the brain

ret, markers = cv2.connectedComponents(thresh)

#Get the area taken by each component. Ignore label 0 since this is the background.
marker_area = [np.sum(markers==m) for m in range(np.max(markers)) if m!=0]

#Get label of largest component by area
largest_component = np.argmax(marker_area)+1 #Add 1 since we dropped zero above 

#Get pixels which correspond to the brain
# brain_mask = markers==largest_component

# brain_out = img.copy()
# #In a copy of the original image, clear those pixels that don't correspond to the brain
# brain_out[brain_mask==False] = (0,0,0)
ShowImage('Stripped brain',largest_component,'gray')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-35-9890e0245a47> in <module>
#       5
#       6 #Get the area taken by each component. Ignore label 0 since this is the background.
# ----> 7 marker_area = [np.sum(markers==m) for m in range(np.max(markers)) if m!=0]
#       8
#       9 #Get label of largest component by area
#
# <ipython-input-35-9890e0245a47> in <listcomp>(.0)
#       5
#       6 #Get the area taken by each component. Ignore label 0 since this is the background.
# ----> 7 marker_area = [np.sum(markers==m) for m in range(np.max(markers)) if m!=0]
#       8
#       9 #Get label of largest component by area
#
# ~\Anaconda3\lib\site-packages\numpy\core\fromnumeric.py in sum(a, axis, dtype, out, keepdims, initial)
#    1928
#    1929     return _wrapreduction(a, np.add, 'sum', axis, dtype, out, keepdims=keepdims,
# ...

# %%
# convert the image to grayscale, blur it, and find edges
# in the image
gray = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)
gray = cv2.GaussianBlur(gray, (5, 5), 0)
edged = cv2.Canny(gray, 75, 200)

plt.imshow(gray, cmap='gray')
plt.title("blurred image")
plt.xticks([]), plt.yticks([])
plt.show()

# show the original image and the edge detected image
print("STEP 1: Edge Detection")

plt.imshow(edged, cmap='gray')
plt.title("Edged image")
plt.xticks([]), plt.yticks([])
plt.show()
# Out:
# STEP 1: Edge Detection

# %%
def ShowImage(title,img,ctype):
  plt.figure(figsize=(8, 8))
  if ctype=='bgr':
    b,g,r = cv2.split(img)       # get b,g,r
    rgb_img = cv2.merge([r,g,b])     # switch it to rgb
    plt.imshow(rgb_img)
  elif ctype=='hsv':
    rgb = cv2.cvtColor(img,cv2.COLOR_HSV2RGB)
    plt.imshow(rgb)
  elif ctype=='gray':
    plt.imshow(img,cmap='gray')
  elif ctype=='rgb':
    plt.imshow(img)
  else:
    raise Exception("Unknown colour type")
  plt.axis('off')
  plt.title(title)
  plt.show()

# %%
#Read in image
img = cv2.imread('images/c_1.jpg')
ShowImage('Chromatography output',img,'gray')

# %%
#Read in image
hsv = cv2.cvtColor(img,cv2.COLOR_BGR2HSV)
ShowImage('Chromatography output',hsv,'gray')

# %%
flags = [i for i in dir(cv2) if i.startswith('COLOR_')]
print(flags)

# %%
# Make a histogram of the intensities in the grayscale image
plt.hist(gray.ravel(),256)
plt.show()

# %%
#let's extract the brain

ret, markers = cv2.connectedComponents(thresh)

#Get the area taken by each component. Ignore label 0 since this is the background.
marker_area = [np.sum(markers==m) for m in range(np.max(markers)) if m!=0]

#Get label of largest component by area
largest_component = np.argmax(marker_area)+1 #Add 1 since we dropped zero above 

#Get pixels which correspond to the brain
# brain_mask = markers==largest_component

# brain_out = img.copy()
# #In a copy of the original image, clear those pixels that don't correspond to the brain
# brain_out[brain_mask==False] = (0,0,0)
ShowImage('Stripped brain',largest_component,'gray')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-34-9890e0245a47> in <module>
#      16 # #In a copy of the original image, clear those pixels that don't correspond to the brain
#      17 # brain_out[brain_mask==False] = (0,0,0)
# ---> 18 ShowImage('Stripped brain',largest_component,'gray')
#
# <ipython-input-3-d2e4b4760f83> in ShowImage(title, img, ctype)
#       9     plt.imshow(rgb)
#      10   elif ctype=='gray':
# ---> 11     plt.imshow(img,cmap='gray')
#      12   elif ctype=='rgb':
#      13     plt.imshow(img)
#
# ~\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2699         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
# ...
